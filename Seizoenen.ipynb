# %%
# KOPIEER DEZE CODE ERGENS WAAR JE CSV BESTAND STAAT, DAN WERKT HET

import matplotlib.pyplot as plt
# %matplotlib inline
# Load library
import numpy as np
import pandas as pd
import csv

# Lente: 21 maart t/m 20 juni
# Zomer: 21 juni t/m 20 september
# Herfst: 21 september t/m 20 december
# Winter: 21 december t/m 20 maart
   
# !!! DIT WERKT WEL !!!
df1 = pd.read_csv("DataGuns.csv")
df2 = df1.set_index("date", drop=False)


# lente 2014
dfl14 = df2.loc["3-21-2014":"6-20-2014", "one":"n_injured"]
il14 = dfl14["one"].sum()
dl14 = dfl14["n_killed"].sum()
gl14 = dfl14["n_injured"].sum()

# zomer 2014
dfz14 = df2.loc["6-21-2014":"9-20-2014", "one":"n_injured"]
iz14 = dfz14["one"].sum()
dz14 = dfz14["n_killed"].sum()
gz14 = dfz14["n_injured"].sum()

# herfst 2014
dfh14 = df2.loc["9-21-2014":"12-20-2014", "one":"n_injured"]
ih14 = dfh14["one"].sum()
dh14 = dfh14["n_killed"].sum()
gh14 = dfh14["n_injured"].sum()

# winter 2014
dfw14 = df2.loc["12-21-2014":"3-20-2015", "one":"n_injured"]
iw14 = dfw14["one"].sum()
dw14 = dfw14["n_killed"].sum()
gw14 = dfw14["n_injured"].sum()

# lente 2015
dfl15 = df2.loc["3-21-2015":"6-20-2015", "one":"n_injured"]
il15 = dfl15["one"].sum()
dl15 = dfl15["n_killed"].sum()
gl15 = dfl15["n_injured"].sum()

# zomer 2015
dfz15 = df2.loc["6-21-2015":"9-20-2015", "one":"n_injured"]
iz15 = dfz15["one"].sum()
dz15 = dfz15["n_killed"].sum()
gz15 = dfz15["n_injured"].sum()

# herfst 2015
dfh15 = df2.loc["9-21-2015":"12-20-2015", "one":"n_injured"]
ih15 = dfh15["one"].sum()
dh15 = dfh15["n_killed"].sum()
gh15 = dfh15["n_injured"].sum()

# winter 2015
dfw15 = df2.loc["12-21-2015":"3-20-2016", "one":"n_injured"]
iw15= dfw15["one"].sum()
dw15 = dfw15["n_killed"].sum()
gw15 = dfw15["n_injured"].sum()

# lente 2016
dfl16 = df2.loc["3-21-2016":"6-20-2016", "one":"n_injured"]
il16 = dfl16["one"].sum()
dl16 = dfl16["n_killed"].sum()
gl16 = dfl16["n_injured"].sum()

# zomer 2016
dfz16 = df2.loc["6-21-2016":"9-20-2016", "one":"n_injured"]
iz16 = dfz16["one"].sum()
dz16 = dfz16["n_killed"].sum()
gz16 = dfz16["n_injured"].sum()

# herfst 2016
dfh16 = df2.loc["9-21-2016":"12-20-2016", "one":"n_injured"]
ih16 = dfh16["one"].sum()
dh16 = dfh16["n_killed"].sum()
gh16 = dfh16["n_injured"].sum()

# winter 2016
dfw16 = df2.loc["12-21-2016":"3-20-2017", "one":"n_injured"]
iw16 = dfw16["one"].sum()
dw16 = dfw16["n_killed"].sum()
gw16 = dfw16["n_injured"].sum()


# il14 = dfl14["one"].sum()
# dl14 = dfl14["n_killed"].sum()
# gl14 = dfl14["n_injured"].sum()

# z14 = 
# h14 = 
# w15 =
# l15 =
# z15 =
# h15 =
# w16 = 
# l16 =
# z16 = 
# h16 =
# w16 =

# print(dfl14["n_killed"].sum())
# print(dfl14["n_injured"].sum())

# print(dfz15["one"].sum())
# print(dfz15["n_killed"].sum())
# print(dfz15["n_injured"].sum())

# print(dfw16["one"].sum())
# print(dfw16["n_killed"].sum())
# print(dfw16["n_injured"].sum())


# print(dfw14)
df13 = df2.loc["1-1-2013":"12-31-2013", "state":"state_senate_district"]
df14 = df2.loc["1-1-2014":"12-31-2014", "state":"state_senate_district"]
df15 = df2.loc["1-1-2015":"12-31-2015", "state":"state_senate_district"]
df16 = df2.loc["1-1-2016":"12-31-2016", "state":"state_senate_district"]
df17 = df2.loc["1-1-2017":"12-31-2017", "state":"state_senate_district"]
df18 = df2.loc["1-1-2018":"3-31-2018", "state":"state_senate_district"]



number_killed_2013 = df13["n_killed"].sum()
number_injured_2013 = df13["n_injured"].sum()

number_killed_2014 = df14["n_killed"].sum()
number_injured_2014 = df14["n_injured"].sum()

number_killed_2015 = df15["n_killed"].sum()
number_injured_2015 = df15["n_injured"].sum()

number_killed_2016 = df16["n_killed"].sum()
number_injured_2016 = df16["n_injured"].sum()

number_killed_2017 = df17["n_killed"].sum()
number_injured_2017 = df17["n_injured"].sum()

number_killed_2018 = df18["n_killed"].sum()
number_injured_2018 = df18["n_injured"].sum()


# grafiek

import plotly.plotly as py
import plotly.graph_objs as go

inc = go.Bar(
    x=['lente 2014', 'zomer 2014', 'herfst 2014', 'winter 2014', 'lente 2015', 'zomer 2015', 'herfst 2015', 'winter 2015', 'lente 2016', 'zomer 2016', 'herfst 2016', 'winter 2016'],
    y=[il14, iz14, ih14, iw14, il15, iz15, ih15, iw15, il16, iz16, ih16, iw16],
    name='Aantal incidenten'
)
dood = go.Bar(
    x=['lente 2014', 'zomer 2014', 'herfst 2014', 'winter 2014', 'lente 2015', 'zomer 2015', 'herfst 2015', 'winter 2015', 'lente 2016', 'zomer 2016', 'herfst 2016', 'winter 2016'],
    y=[dl14, dz14, dh14, dw14, dl15, dz15, dh15, dw15, dl16, dz16, dh16, dw16],
    name='Aantal doden'
)
gew = go.Bar(
    x=['lente 2014', 'zomer 2014', 'herfst 2014', 'winter 2014', 'lente 2015', 'zomer 2015', 'herfst 2015', 'winter 2015', 'lente 2016', 'zomer 2016', 'herfst 2016', 'winter 2016'],
    y=[gl14, gz14, gh14, gw14, gl15, gz15, gh15, gw15, gl16, gz16, gh16, gw16],
    name='Aantal gewonden'
)


data = [inc, dood, gew]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# c:\users\sander\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning:
#
# Columns (0,1,2,7,8,12,13,14,15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SanderVonk/14.embed" height="525px" width="100%"></iframe>

# %%
# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api

import plotly
plotly.tools.set_credentials_file(username='SanderVonk', api_key='u5pe4b8mCyWa0hSiZvnq')
import matplotlib.pyplot as plt
from matplotlib.dates import date2num
import datetime
import plotly.plotly as py

print(il14)
print(dl14)
print(gl14)
multiple_bars = plt.figure()

# x = [datetime.datetime(2011, 1, 4, 0, 0),
#      datetime.datetime(2011, 1, 5, 0, 0),
#      datetime.datetime(2011, 1, 6, 0, 0)]
# x = date2num(x)
x = [1, 2, 3]
y = [4, 9, 2]
z = [1,2,3]
k = [11,12,13]

# ax = plt.subplot(111)
# ax.bar(x-0.2, y,width=0.2,color='b',align='center')
# ax.bar(x, z,width=0.2,color='g',align='center')
# ax.bar(x+0.2, k,width=0.2,color='r',align='center')
# ax.xaxis_date()

plt.show()

import plotly
plotly.tools.set_credentials_file(username='SanderVonk', api_key='u5pe4b8mCyWa0hSiZvnq')plot_url = py.plot_mpl(multiple_bars, filename='mpl-multiple-bars')

# %%
import plotly
plotly.tools.set_credentials_file(username='SanderVonk', api_key='u5pe4b8mCyWa0hSiZvnq')
import plotly.plotly as py
# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api


y = [3, 10, 7, 5, 3, 4.5, 6, 8.1]
N = len(y)
x = [1, 2, 3, 4, 5, 6, 7, 8]
p = [8, 7, 6, 5, 4, 3, 2, 1]
q = [2, 4, 6, 8, 10, 12, 14, 16]
width = 1/1.5
plt.bar(x, y, width, color="red")

fig = plt.figure()

# fig = plt.gcf()
plot_url = py.plot_mpl(fig, filename='mpl-basic-bar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-d126b17e729a> in <module>()
#      17
#      18 # fig = plt.gcf()
# ---> 19 plot_url = py.plot_mpl(fig, filename='mpl-basic-bar')
#
# c:\users\sander\appdata\local\programs\python\python36-32\lib\site-packages\plotly\plotly\plotly.py in plot_mpl(fig, resize, strip_style, update, **plot_options)
#     301
#     302     """
# --> 303     fig = tools.mpl_to_plotly(fig, resize=resize, strip_style=strip_style)
#     304     if update and isinstance(update, dict):
#     305         fig.update(update)
#
# c:\users\sander\appdata\local\programs\python\python36-32\lib\site-packages\plotly\tools.py in mpl_to_plotly(fig, resize, strip_style, verbose)
#     463     if matplotlylib:
#     464         renderer = matplotlylib.PlotlyRenderer()
# --> 465         matplotlylib.Exporter(renderer).run(fig)
#     466         if resize:
#     467             renderer.resize()
#
# c:\users\sander\appdata\local\programs\python\python36-32\lib\site-packages\plotly\matplotlylib\mplexporter\exporter.py in run(self, fig)
#      47             import matplotlib.pyplot as plt
#      48             plt.close(fig)
# ---> 49         self.crawl_fig(fig)
#      50
#      51     @staticmethod
#
# c:\users\sander\appdata\local\programs\python\python36-32\lib\site-packages\plotly\matplotlylib\mplexporter\exporter.py in crawl_fig(self, fig)
#     112         """Crawl the figure and process all axes"""
#     113         with self.renderer.draw_figure(fig=fig,
# --> 114                                        props=utils.get_figure_properties(fig)):
#     115             for ax in fig.axes:
#     116                 self.crawl_ax(ax)
#
# c:\users\sander\appdata\local\programs\python\python36-32\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# c:\users\sander\appdata\local\programs\python\python36-32\lib\site-packages\plotly\matplotlylib\mplexporter\renderers\base.py in draw_figure(self, fig, props)
#      41         self._current_fig = fig
#      42         self._fig_props = props
# ---> 43         self.open_figure(fig=fig, props=props)
#      44         yield
#      45         self.close_figure(fig=fig)
#
# c:\users\sander\appdata\local\programs\python\python36-32\lib\site-packages\plotly\matplotlylib\renderer.py in open_figure(self, fig, props)
#      83             autosize=False,
#      84             hovermode='closest')
# ---> 85         self.mpl_x_bounds, self.mpl_y_bounds = mpltools.get_axes_bounds(fig)
#      86         margin = go.Margin(
#      87             l=int(self.mpl_x_bounds[0] * self.plotly_fig['layout']['width']),
#
# c:\users\sander\appdata\local\programs\python\python36-32\lib\site-packages\plotly\matplotlylib\mpltools.py in get_axes_bounds(fig)
#     253         y_min.append(bounds[1])
#     254         y_max.append(bounds[1]+bounds[3])
# --> 255     x_min, y_min, x_max, y_max = min(x_min), min(y_min), max(x_max), max(y_max)
#     256     return (x_min, x_max), (y_min, y_max)
#     257
#
# ValueError: min() arg is an empty sequence

# %%
import matplotlib.pyplot as plt
import plotly.plotly as py

multiple_bars = plt.figure()

x = [datetime.datetime(2011, 1, 4, 0, 0),
     datetime.datetime(2011, 1, 5, 0, 0),
     datetime.datetime(2011, 1, 6, 0, 0)]
x = date2num(x)

y = [4, 9, 2]
z=[1,2,3]
k=[11,12,13]

ax = plt.subplot(111)
ax.bar(x-0.2, y,width=0.2,color='b',align='center')
ax.bar(x, z,width=0.2,color='g',align='center')
ax.bar(x+0.2, k,width=0.2,color='r',align='center')
ax.xaxis_date()

plt.show()

plot_url = py.plot_mpl(multiple_bars, filename='mpl-multiple-bars')

# %%
import plotly.plotly as py
import numpy as np
import matplotlib.pyplot as plt
import datetime

# Lente: 21 maart t/m 20 juni
# Zomer: 21 juni t/m 20 september
# Herfst: 21 september t/m 20 december
# Winter: 21 december t/m 20 maart

date = plt.figure()

x = [datetime.datetime(2014, 3, 21),
    datetime.datetime(2014, 6, 21),
    datetime.datetime(2014, 9, 21)]
y = [4, 9, 2]

ax = plt.subplot(111)
ax.bar(x, y, width=4)
ax.xaxis_date()

plot_url = py.plot_mpl(date, filename='mpl-date-example')

# %%
import matplotlib.pyplot as plt
import numpy as np

import plotly.plotly as py
import plotly.tools as tls
# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api

mpl_fig = plt.figure()
ax = mpl_fig.add_subplot(111)

N = 5
menMeans = (20, 35, 30, 35, 27, 30, 30, 30, 30 ,30 ,30, 30)
womenMeans = (25, 32, 34, 20, 25, 30, 30 ,30 ,30 ,30 ,30, 30)
menStd = (2, 3, 4, 1, 2, 3, 3, 3, 3, 3, 3, 3)
womenStd = (3, 5, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = len(x)      # the width of the bars: can also be len(x) sequence

p1 = ax.bar(ind, menMeans, width, color=(0.2588,0.4433,1.0))
p2 = ax.bar(ind, womenMeans, width, color=(1.0,0.5,0.62),
             bottom=menMeans)
ax.set_ylabel('Scores')
ax.set_xlabel('Groups')
ax.set_title('Scores by group and gender')

ax.set_xticks(ind + width/2.)
ax.set_yticks(np.arange(0, 81, 10))
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'G11', 'G12'))

plotly_fig = tls.mpl_to_plotly( mpl_fig )

# For Legend
plotly_fig["layout"]["showlegend"] = True
plotly_fig["data"][0]["name"] = "Men"
plotly_fig["data"][1]["name"] = "Women"


plot_url = py.plot(plotly_fig, filename='stacked-bar-chart')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-583fcdc5f685> in <module>()
#      18 width = len(x)      # the width of the bars: can also be len(x) sequence
#      19
# ---> 20 p1 = ax.bar(ind, menMeans, width, color=(0.2588,0.4433,1.0))
#      21 p2 = ax.bar(ind, womenMeans, width, color=(1.0,0.5,0.62),
#      22              bottom=menMeans)
#
# c:\users\sander\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# c:\users\sander\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py in bar(self, *args, **kwargs)
#    2231         x, height, width, y, linewidth = np.broadcast_arrays(
#    2232             # Make args iterable too.
# -> 2233             np.atleast_1d(x), height, width, y, linewidth)
#    2234
#    2235         # Now that units have been converted, set the tick locations.
#
# c:\users\sander\appdata\local\programs\python\python36-32\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     247     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     248
# --> 249     shape = _broadcast_shape(*args)
#     250
#     251     if all(array.shape == shape for array in args):
#
# c:\users\sander\appdata\local\programs\python\python36-32\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     182     # use the old-iterator because np.nditer does not handle size 0 arrays
#     183     # consistently
# --> 184     b = np.broadcast(*args[:32])
#     185     # unfortunately, it cannot handle 32 or more arguments directly
#     186     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
import plotly.plotly as py
plotly.tools.set_credentials_file(username='SanderVonk', api_key='u5pe4b8mCyWa0hSiZvnq')
from plotly.graph_objs import *
py.sign_in('SanderVonk', 'u5pe4b8mCyWa0hSiZvnq')
trace1 = {
  "x": [0.175, 1.175, 2.175, 3.175, "4.175", "5.175", "6.175", "7.175", "8.175", "9.175", "10.175", "11.175", "12.175"], 
  "y": [20, 35, 30, 35, 27, "30", "30", "30", "30", "30", "30", "30", "30"], 
  "marker": {
    "color": "#4171FF", 
    "line": {"width": 1}
  }, 
  "name": "Men, y", 
  "opacity": 1, 
  "orientation": "v", 
  "type": "bar", 
  "uid": "43ab4f", 
  "xaxis": "x", 
  "xsrc": "SanderVonk:8:1e6e2d", 
  "yaxis": "y", 
  "ysrc": "SanderVonk:8:ee28c5"
}
trace2 = {
  "x": [0.175, 1.175, 2.175, 3.175, "4.175", "5.175", "6.175", "7.175", "8.175", "9.175", "10.175", "11.175", "12.175"], 
  "y": [25, 32, 34, 20, 25, "30", "30", "30", "30", "30", "30", "40", "30"], 
  "marker": {
    "color": "#FF7F9E", 
    "line": {"width": 1}
  }, 
  "name": "Women, y", 
  "opacity": 1, 
  "orientation": "v", 
  "type": "bar", 
  "uid": "8d00a5", 
  "xaxis": "x", 
  "xsrc": "SanderVonk:8:1e6e2d", 
  "yaxis": "y", 
  "ysrc": "SanderVonk:8:e5e8ec"
}
data = Data([trace1, trace2])
layout = {
  "autosize": False, 
  "bargap": 0.65, 
  "barmode": "stack", 
  "height": 480, 
  "hovermode": "x", 
  "margin": {
    "r": 63, 
    "t": 47, 
    "b": 47, 
    "l": 80, 
    "pad": 0
  }, 
  "showlegend": True, 
  "title": "Scores by group and gender", 
  "titlefont": {
    "color": "#000000", 
    "size": 14.4
  }, 
  "width": 640, 
  "xaxis": {
    "anchor": "y", 
    "autorange": True, 
    "domain": [0, 1], 
    "dtick": 1, 
    "mirror": "ticks", 
    "range": [-0.325, 12.675], 
    "showgrid": False, 
    "showline": True, 
    "side": "bottom", 
    "tick0": 0.175, 
    "tickfont": {"size": 12}, 
    "tickmode": False, 
    "ticks": "inside", 
    "title": "Groups", 
    "titlefont": {
      "color": "#000000", 
      "size": 12
    }, 
    "type": "linear", 
    "zeroline": False
  }, 
  "yaxis": {
    "anchor": "x", 
    "autorange": True, 
    "domain": [0, 1], 
    "dtick": 10, 
    "mirror": "ticks", 
    "range": [0, 73.6842105263], 
    "showgrid": False, 
    "showline": True, 
    "side": "left", 
    "tick0": 0, 
    "tickfont": {"size": 12}, 
    "tickmode": False, 
    "ticks": "inside", 
    "title": "Scores", 
    "titlefont": {
      "color": "#000000", 
      "size": 12
    }, 
    "type": "linear", 
    "zeroline": False
  }
}
fig = Figure(data=data, layout=layout)
plot_url = py.plot(fig)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x=['giraffes', 'orangutans', 'monkeys'],
    y=[20, 14, 23],
    name='SF Zoo'
)
trace2 = go.Bar(
    x=['giraffes', 'orangutans', 'monkeys'],
    y=[12, 18, 29],
    name='LA Zoo'
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='stack'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='stacked-bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SanderVonk/12.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x=['lente 2014', 'zomer 2014', 'herfst 2014', 'winter 2014', 'lente 2015', 'zomer 2015', 'herfst 2015', 'winter 2015', 'lente 2016', 'zomer 2016', 'herfst 2016', 'winter 2016'],
    y=[20, 14, 23, 14, 23, 14, 23, 23, 14, 23, 23, 14],
    name='Aantal incidenten'
)
trace2 = go.Bar(
    x=['lente 2014', 'zomer 2014', 'herfst 2014', 'winter 2014', 'lente 2015', 'zomer 2015', 'herfst 2015', 'winter 2015', 'lente 2016', 'zomer 2016', 'herfst 2016', 'winter 2016'],
    y=[12, 18, 29, 23, 14, 23, 23, 14, 23, 23, 14, 23],
    name='Aantal gewonden'
)

trace3 = go.Bar(
    x=['lente 2014', 'zomer 2014', 'herfst 2014', 'winter 2014', 'lente 2015', 'zomer 2015', 'herfst 2015', 'winter 2015', 'lente 2016', 'zomer 2016', 'herfst 2016', 'winter 2016'],
    y=[21, 18, 9, 23, 14, 23, 23, 14, 23, 23, 14, 23],
    name='Aantal doden'
)
data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')


# # lente 2014
# dfl14 = df2.loc["3-21-2014":"6-20-2014", "one":"n_injured"]
# il14 = dfl14["one"].sum()
# dl14 = dfl14["n_killed"].sum()
# gl14 = dfl14["n_injured"].sum()

# # zomer 2014
# dfz14 = df2.loc["6-21-2014":"9-20-2014", "one":"n_injured"]
# iz14 = dfz14["one"].sum()
# dz14 = dfz14["n_killed"].sum()
# gz14 = dfz14["n_injured"].sum()

# # herfst 2014
# dfh14 = df2.loc["9-21-2014":"12-20-2014", "one":"n_injured"]
# ih14 = dfh14["one"].sum()
# dh14 = dfh14["n_killed"].sum()
# gh14 = dfh14["n_injured"].sum()

# # winter 2014
# dfw14 = df2.loc["12-21-2014":"3-20-2015", "one":"n_injured"]
# iw14 = dfw14["one"].sum()
# dw14 = dfw14["n_killed"].sum()
# gw14 = dfw14["n_injured"].sum()

# # lente 2015
# dfl15 = df2.loc["3-21-2015":"6-20-2015", "one":"n_injured"]
# il15 = dfl15["one"].sum()
# dl15 = dfl15["n_killed"].sum()
# gl15 = dfl15["n_injured"].sum()

# # zomer 2015
# dfz15 = df2.loc["6-21-2015":"9-20-2015", "one":"n_injured"]
# iz15 = dfz15["one"].sum()
# dz15 = dfz15["n_killed"].sum()
# gz15 = dfz15["n_injured"].sum()

# # herfst 2015
# dfh15 = df2.loc["9-21-2015":"12-20-2015", "one":"n_injured"]
# ih15 = dfh15["one"].sum()
# dh15 = dfh15["n_killed"].sum()
# gh15 = dfh15["n_injured"].sum()

# # winter 2015
# dfw15 = df2.loc["12-21-2015":"3-20-2016", "one":"n_injured"]
# iw15= dfw15["one"].sum()
# dw15 = dfw15["n_killed"].sum()
# gw15 = dfw15["n_injured"].sum()

# # lente 2016
# dfl16 = df2.loc["3-21-2016":"6-20-2016", "one":"n_injured"]
# il16 = dfl16["one"].sum()
# dl16 = dfl16["n_killed"].sum()
# gl16 = dfl16["n_injured"].sum()

# # zomer 2016
# dfz16 = df2.loc["6-21-2016":"9-20-2016", "one":"n_injured"]
# iz16 = dfz16["one"].sum()
# dz16 = dfz16["n_killed"].sum()
# gz16 = dfz16["n_injured"].sum()

# # herfst 2016
# dfh16 = df2.loc["9-21-2016":"12-20-2016", "one":"n_injured"]
# ih16 = dfh16["one"].sum()
# dh16 = dfh16["n_killed"].sum()
# gh16 = dfh16["n_injured"].sum()

# # winter 2016
# dfw16 = df2.loc["12-21-2016":"3-20-2017", "one":"n_injured"]
# iw16 = dfw16["one"].sum()
# dw16 = dfw16["n_killed"].sum()
# gw16 = dfw16["n_injured"].sum()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SanderVonk/14.embed" height="525px" width="100%"></iframe>
