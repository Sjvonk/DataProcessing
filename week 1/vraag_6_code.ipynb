# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd
import csv

df1 = pd.read_csv("DataGun.csv")

print(df1.loc[df1['n_killed'] > 9])
# Out:
#              date                 state            city_or_county  n_killed  \
# 194     9/16/2013  District of Columbia      Washington Navy Yard        11
# 92624   10/1/2015                Oregon                  Roseburg        10
# 101531  12/2/2015            California            San Bernardino        16
# 130448  6/12/2016               Florida                   Orlando        50
# 217151  11/5/2017                 Texas        Sutherland Springs        27
# 232745  2/14/2018               Florida  Pompano Beach (Parkland)        17
#
#         n_injured  congressional_district  \
# 194             3                     1.0
# 92624           9                     4.0
# 101531         19                    31.0
# 130448         53                     5.0
# 217151         20                    28.0
# 232745         17                    22.0
#
#                                                  gun_type  \
# 194                                    0::9mm||1::Shotgun
# ...
